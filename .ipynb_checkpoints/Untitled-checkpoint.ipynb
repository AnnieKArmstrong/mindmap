# %%
import pandas as pd
import openpyxl
import xlrd
import matplotlib.pyplot as plt
import numpy as np
import networkx
pd.options.display.max_rows = 400

# %%
X = pd.ExcelFile("C:/Users/Annie Armstrong/Documents/Github/mindmap/grp_edgelists/grp-edgelist.xlsx")
mindmap_df = X.parse("Individual lists")
grpmindmap_df = X.parse("Group list")

# %%
septmw_df = mindmap_df.query('Group == "MW" & Month == "September"')
septmw_df.head(5)
# Out:
#           Edge           Target      Month Group StudentID StudentStatus  \
# 0  Bronx River              Rat  September    MW       1MW      Returner
# 1          Rat              Cat  September    MW       1MW      Returner
# 2  Bronx River        LaGuardia  September    MW       2MW           New
# 3  Bronx River          6 Train  September    MW       2MW           New
# 4      6 Train  Pelham Bay Park  September    MW       2MW           New
#
#      QualitativeCode QualitativeCode2   Valence  Unnamed: 9  Unnamed: 10  \
# 0            Animals              NaN  Negative         NaN          NaN
# 1            Animals              NaN       NaN         NaN          NaN
# 2  Places you can go              NaN       NaN         NaN          NaN
# 3     Transportation              NaN       NaN         NaN          NaN
# 4  Places you can go              NaN       NaN         NaN          NaN
#
#    Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  Unnamed: 15  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 16
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
G = networkx.from_pandas_edgelist(mindmap_df, 'Edge', 'Target')
networkx.write_graphml(G, 'individual.graphml')
print('individual maps', G.number_of_nodes(), G.number_of_edges())
# Out:
# individual maps 228 278
